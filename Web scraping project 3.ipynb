# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import time
from selenium.common.exceptions import NoSuchElementException

# %% [markdown]
# Q1. Write a python program which searches all the product under a particular product vertical
# from www.amazon.in. The product verticals to be searched will be taken as input from user.
# For e.g. If user input is ‘guitar’. Then search for guitars.
# Q2. In the above question, now scrape the following details of each product listed in first 3 pages
# of your search results and save it in a data frame and csv. In case if any product vertical has
# less than 3 pages in search results then scrape all the products available under that product
# vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of
# Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details"
# and “Product URL”. In case, if any of the details are missing for any of the product then
# replace it by “-“

# %%
url =  'https://www.amazon.in/'
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
driver.get(url)
# Out:
# <ipython-input-5-562a4c25de6a>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")

# %%
item = input("Enter an Item to search: ")
# Out:
# Enter an Item to search: Laptop

# %%
search = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys(item)
search = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
search.click()
# Out:
# <ipython-input-9-e3f203eca0a7>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
# <ipython-input-9-e3f203eca0a7>:3: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')

# %%
produrl =[]

# %%
produrl_tag = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
# Out:
# <ipython-input-11-19fb6df29503>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   produrl_tag = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")

# %%
for u in produrl_tag:
 try: 
     produrl.append(u.get_attribute("href"))
 except:
    produrl.append('-')

# %%
import time 


i=2

while(i>0): 
    nextbtn = driver.find_element_by_xpath("//li[@class='a-last']")
    nextbtn.click()
    time.sleep(3)
    produrl_tag = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for u in produrl_tag:
          produrl.append(u.get_attribute("href"))
    i=i-1
# Out:
# <ipython-input-13-496f8f067b95>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   nextbtn = driver.find_element_by_xpath("//li[@class='a-last']")
# <ipython-input-13-496f8f067b95>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   produrl_tag = driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")

# %%
Brand = []
prod = []
rate = []
ratenum = []
price = []
ex = []
delv = []
avl = []
det = []

# %%
for i in produrl:
    driver.get(i)
    time.sleep(5)
    try:
        brandtag = driver.find_element_by_xpath("//td[@class='a-size-base prodDetAttrValue']")
        Brand.append(brandtag.text)
    except:
        Brand.append('-')
    try:
        prodtag = driver.find_element_by_xpath("//span[@class='a-size-large product-title-word-break']")
        prod.append(prodtag.text)
    except:
        prod.append('-')
    try:
        ratetag = driver.find_element_by_xpath("//div[@id='averageCustomerReviews']//span[@class='a-icon-alt']")
        rate.append(ratetag.get_attribute("innerHTML"))
    except NoSuchElementException:
        rate.append('-')
    try:
        ratenumtag = driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
        ratenum.append(ratenumtag.get_attribute("innerHTML"))
    except:
        ratenum.append('-')
    try:
        pricetag = driver.find_element_by_xpath("//span[@id='priceblock_ourprice']")
        price.append(pricetag.text)
    except:
        price.append('-')
    
    try:
        extag = driver.find_element_by_xpath("//div[@class='a-accordion-row-a11y']//h5")
        ex.append(extag.text.replace('\n',' ').replace('   ',''))
    except:
        ex.append('-')
    
    try:
        delvtag = driver.find_element_by_xpath("//div[@id='ddmDeliveryMessage']//b")
        delv.append(delvtag.text)
    except:
        delv.append('-')
    try:
        avltag = driver.find_element_by_xpath("//div[@id='availability']//span")
        avl.append(avltag.text)
    except:
        avl.append('-')
    try:
        dettag = driver.find_element_by_xpath("//div[@id='feature-bullets']")
        det.append(dettag.text.replace('\nShow More','.').replace('\n',''))
    except:
        det.append('-')
# Out:
# <ipython-input-15-1ad6ac302e37>:5: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brandtag = driver.find_element_by_xpath("//td[@class='a-size-base prodDetAttrValue']")
# <ipython-input-15-1ad6ac302e37>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prodtag = driver.find_element_by_xpath("//span[@class='a-size-large product-title-word-break']")
# <ipython-input-15-1ad6ac302e37>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ratetag = driver.find_element_by_xpath("//div[@id='averageCustomerReviews']//span[@class='a-icon-alt']")
# <ipython-input-15-1ad6ac302e37>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ratenumtag = driver.find_element_by_xpath("//span[@id='acrCustomerReviewText']")
# <ipython-input-15-1ad6ac302e37>:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pricetag = driver.find_element_by_xpath("//span[@id='priceblock_ourprice']")
# <ipython-input-15-1ad6ac302e37>:31: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   extag = driver.find_element_by_xpath("//div[@class='a-accordion-row-a11y']//h5")
# <ipython-input-15-1ad6ac302e37>:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   delvtag = driver.find_element_by_xpath("//div[@id='ddmDeliveryMessage']//b")
# <ipython-input-15-1ad6ac302e37>:42: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   avltag = driver.find_element_by_xpath("//div[@id='availability']//span")
# <ipython-input-15-1ad6ac302e37>:47: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dettag = driver.find_element_by_xpath("//div[@id='feature-bullets']")

# %%
Laptops = {'Brand Name':Brand,'Product Name':prod,'Price(₹)':price,'Rating':rate,'Number of Ratings':ratenum ,'Exchange':ex,'Expected Delivery':delv,'Availablitiy':avl,'Details':det,'Product URL':produrl}

Laptops  = pd.DataFrame(Laptops)

# %%
Laptops
# Out:
#    Brand Name                                       Product Name Price(₹)  \
# 0        Acer  Acer Nitro 5 AN515-57 Gaming Laptop | Intel Co...        -
# 1          HP  HP 15 Ryzen 3 Thin & Light 15.6-inch (39.6 cms...        -
# 2        ASUS  ASUS VivoBook 15 (2020), 39.6 cm HD, Dual Core...        -
# 3        Dell  Dell Vostro 3405 14" (35.56cms) HD AG Display ...        -
# 4      Lenovo  Lenovo IdeaPad Slim 1 Intel Celeron N4020 11.6...        -
# ..        ...                                                ...      ...
# 67         HP  HP 15 11th Gen Intel Core i5 Processor 39.62 c...        -
# 68       ASUS  ASUS TUF Gaming F15 Laptop 15.6" (39.62 cms) F...        -
# 69     Lenovo  Lenovo ThinkBook 15 Intel 11th Gen Core i5 15....        -
# 70     Lenovo  Lenovo ThinkBook 13s Intel 11th Gen Core i7 13...        -
# 71     Lenovo  Lenovo Yoga 6 AMD Ryzen 7 5700U 13.3" (33.782c...        -
#
#                 Rating Number of Ratings  \
# 0   4.1 out of 5 stars       379 ratings
# 1   4.1 out of 5 stars       162 ratings
# 2   4.2 out of 5 stars       843 ratings
# 3   3.7 out of 5 stars        41 ratings
# 4   4.0 out of 5 stars       136 ratings
# ..                 ...               ...
# 67  4.2 out of 5 stars       383 ratings
# 68  4.4 out of 5 stars     2,038 ratings
# 69  4.1 out of 5 stars        10 ratings
# 70  4.3 out of 5 stars        30 ratings
# 71  4.1 out of 5 stars        84 ratings
#
#                                 Exchange  Expected Delivery  \
# 0      With Exchange Up to 18,550.00 off    Tuesday, Dec 14
# 1      With Exchange Up to 18,550.00 off    Tuesday, Dec 14
# 2                                      -                  -
# 3                                      -                  -
# 4      With Exchange Up to 18,550.00 off        Dec 15 - 18
# ..                                   ...                ...
# 67     With Exchange Up to 18,550.00 off   Saturday, Dec 18
# 68     With Exchange Up to 18,550.00 off   Thursday, Dec 16
# 69  Lightning Deal ₹58,990.00 (Save 48%)        Dec 14 - 15
# 70     With Exchange Up to 18,550.00 off     Sunday, Dec 19
# 71     With Exchange Up to 18,550.00 off  Wednesday, Dec 15
#
#              Availablitiy                                            Details  \
# 0               In stock.  About this itemDominate the Game: Great perfor...
# 1               In stock.  About this itemFree upgrade to Windows 11 when...
# 2                          About this itemFree upgrade to Windows 11 when...
# 3                          About this itemProcessor: AMD Athlon Silver 30...
# 4   Only 1 left in stock.  About this itemFree upgrade to Windows 11 when...
# ..                    ...                                                ...
# 67              In stock.  About this itemFree upgrade to Windows 11 when...
# 68              In stock.  About this itemFree upgrade to Windows 11 when...
# 69                         About this itemThinkBook 15 Reliability tested...
# 70              In stock.  About this itemThinkBook 13s Reliability teste...
# 71              In stock.  About this itemProcessor: AMD Ryzen 7 5700U | ...
#
#                                           Product URL
# 0   https://www.amazon.in/gp/slredirect/picassoRed...
# 1   https://www.amazon.in/gp/slredirect/picassoRed...
# 2   https://www.amazon.in/ASUS-VivoBook-Integrated...
# 3   https://www.amazon.in/Dell-35-56cms-Integrated...
# 4   https://www.amazon.in/Lenovo-IdeaPad-Celeron-P...
# ..                                                ...
# 67  https://www.amazon.in/HP-Processor-15-6-inch-L...
# 68  https://www.amazon.in/ASUS-i5-10300H-Graphics-...
# 69  https://www.amazon.in/gp/slredirect/picassoRed...
# 70  https://www.amazon.in/gp/slredirect/picassoRed...
# 71  https://aax-eu.amazon.in/x/c/QlQ8ElFStCo1-pWTK...
#
# [72 rows x 10 columns]

# %% [markdown]
# Q3. Write a python program to access the search bar and search button on images.google.com and
# scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.

# %%
Q3
# Activating the chrome browser
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
time.sleep(3)

# Opening the google images
url = "https://images.google.com/"
driver.get(url)


search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("fruits")       # Inputing "banana" keyword to search rock images
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Finding the xpath of search button
search_button.click()        # Clicking the search button


# 500 time we scroll down by 10000 in order to generate more images on the website
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")
    
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
# Out:
# <ipython-input-4-f87b0e3abb52>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")
# <ipython-input-4-f87b0e3abb52>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
# <ipython-input-4-f87b0e3abb52>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Finding the xpath of search button
# <ipython-input-4-f87b0e3abb52>:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %% [markdown]
# Q4...Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on
# www.flipkart.com and scrape following details for all the search results displayed on 1st page.
# Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”,
# “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display
# Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”.
# Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe
# and CSV.

# %%
#Q4
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
time.sleep(3)

url = "https://www.flipkart.com/"
driver.get(url)
# Out:
# <ipython-input-11-ab5633b656f8>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")

# %%
#locating the search bar
search_bar=driver.find_element_by_class_name("_3704LK")
search_bar.send_keys('iPhone')

time.sleep(2)
#locating the button and clicking it toh search for sunglasses
button=driver.find_element_by_class_name('L0Z3Pu')
button.click()
# Out:
# <ipython-input-12-cd9bc0568b1a>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar=driver.find_element_by_class_name("_3704LK")
# <ipython-input-12-cd9bc0568b1a>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button=driver.find_element_by_class_name('L0Z3Pu')

# %%
# so lets extract all the tags having the brand-titles
titles_tags=driver.find_elements_by_xpath("//div[@class = '_4rR01T']")
titles_tags
# Out:
# <ipython-input-13-163e9ff947b0>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   titles_tags=driver.find_elements_by_xpath("//div[@class = '_4rR01T']")
# [<selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="b66089b8-85fe-410f-952c-35831d7dd703")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="ae494d46-7e1e-4e08-b2fc-d5b577e5692f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="6ee3842c-0b87-4ba4-8e73-a439fc0a934c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="9adb4d67-64ec-4196-91d0-6749405be08e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="7cfadaa3-f80a-4a37-8080-a8c4a082b4c3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="dc1be9b9-bc72-4aa4-960c-0404e7356219")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="23e02f7b-848a-4fea-8d61-4813ea3438c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="ecf36c56-f770-4771-af81-56a5c36c4253")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="43f6c454-a08c-4c18-bfb9-c7d9c6f62b93")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="44166c5f-3238-42b2-9b03-e760d1958922")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="74243137-eb18-4f2a-9319-0c745aedb543")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="e6211baa-85de-4ba2-bff9-37ce20070f63")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="e6e945a7-12ec-4706-88c2-4e33a4058b70")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="348df013-971e-4cbc-8f4d-462dcca4aaa5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="dca84eea-48f2-4f56-aa74-ad827b6375e5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="3af1e46a-c3a8-4bb9-a70f-e4fb72e90aa4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="019f681a-8718-4ee2-a141-cfd5c279d913")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="fe8d7fba-5044-446c-bcfc-10480dc03002")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="b283ad0f-b118-40e2-869f-5985af51bb7e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="4fbad8c9-3d45-476a-a3c2-f7bd22d9c29f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="fcac7006-336c-433a-833d-f3d8d8efa032")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="9c7ae562-30b0-45e6-b745-3e75433cdf57")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="ed9203a4-b570-428c-b951-4e4f3210ddc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fb72cc2b3abf9980d13d11d0fe319916", element="11e4b52e-fe11-4a8e-a60e-203bec95c2e2")>]

# %% [markdown]
# Q5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on
# google maps

# %%
#Q5 Importing Libraries
# Activating the chrome browser
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
time.sleep(2)

# opening google maps
url = "https://www.google.co.in/maps"
driver.get(url)
time.sleep(2)


search = driver.find_element_by_id("searchboxinput")                       # locating search bar
search.clear()                                                             # clearing search bar
time.sleep(2)
search.send_keys("New Delhi")                                                     # entering values in search bar
button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
button.click()                                                             # clicking search button
time.sleep(3)

try:
    url_string = driver.current_url
    print("URL Extracted: ", url_string)
    lat_lng = re.findall(r'@(.*)data',url_string)
    if len(lat_lng):
        lat_lng_list = lat_lng[0].split(",")
        if len(lat_lng_list)>=2:
            lat = lat_lng_list[0]
            lng = lat_lng_list[1]
        print("Latitude = {}, Longitude = {}".format(lat, lng))

except Exception as e:
        print("Error: ", str(e))
# Out:
# <ipython-input-8-7b5e58421595>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")
# <ipython-input-8-7b5e58421595>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id("searchboxinput")                       # locating search bar
# <ipython-input-8-7b5e58421595>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_id("searchbox-searchbutton")               # locating search button
# URL Extracted:  https://www.google.co.in/maps/place/New+Delhi,+Delhi/@28.5272803,77.0688981,11z/data=!3m1!4b1!4m5!3m4!1s0x390cfd5b347eb62d:0x52c2b7494e204dce!8m2!3d28.6139391!4d77.2090212
# Latitude = 28.5272803, Longitude = 77.0688981

# %% [markdown]
# Q7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
#Q7
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re
data=[]

driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
time.sleep(3)

url = "https://www.digit.in/top-products/best-gaming-laptops-40.html"
driver.get(url)
# so lets extract all the tags having the name-titles
titles_tags=driver.find_elements_by_xpath("//div[@class ='right-container']/div/a/h3")
titles_tags
# Out:
# <ipython-input-23-8078932a623d>:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")
# <ipython-input-23-8078932a623d>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   titles_tags=driver.find_elements_by_xpath("//div[@class ='right-container']/div/a/h3")
# [<selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="741d3526-a1a2-4feb-b3cf-a94cfbd23652")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="31d7a025-fec4-4dba-83d1-575f44909296")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="4b10d6ef-4015-41b8-a7f2-5bf977746e25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="8bea5cbc-f4fe-4999-bba5-cfb09528e6d6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="9c8b1f9e-c88c-4651-be36-131b2735f028")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="32916c81-6151-4ec2-b153-b490081b350e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="7d13aadb-f3d5-4e8e-bca4-cdeafe3f875e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="57243ecd-0c49-4a4b-9701-8ea5d1e3d0cd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="90fa8e18-87ba-4d30-8db2-688d4e10e78b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="0b0e0b02bdaddd93b7b6493273b0945c", element="38435ada-aa61-45d4-abb7-35dc851c2930")>]

# %% [markdown]
# Q8. Write a python program to scrape the details for all billionaires from www.forbes.com.
# Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”,
# “Industry”

# %%
import selenium
import pandas as pd
import numpy as np
from selenium import webdriver
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Activating the chrome browser
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
time.sleep(2)

# Opening the forbes.com
url = "https://www.forbes.com/?sh=69e6b8c92254"
driver.get(url)
time.sleep(2)

#clicking the explore button
button = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
button.click()
time.sleep(1)

#select billioners 
billioners = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
billioners.click()
time.sleep(1)

#select world billioners 
world_billioners= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_billioners.click()
time.sleep(1)


#make empty listes
Rank = [] 
Person_Name = [] 
total_net_worth = [] 
Age = []
country_of_citizenship = [] 
Source = []
industry = []


while(True):
    #scraping rank of billionaire
    rank= driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rank:
        Rank.append(i.text)
    time.sleep(1)
    
    #scraping name of billionaire
    name= driver.find_elements_by_xpath("//div[@class='personName']//div")
    for i in name:
        Person_Name.append(i.text)
    time.sleep(1)
    
     #scraping Age of billionaire
    age= driver.find_elements_by_xpath("//div[@class='age']//div")
    for i in age:
        Age.append(i.text)   
    time.sleep(1)
    
    #scraping citizenship of billionaire    
    citizenship= driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in citizenship:
        country_of_citizenship.append(i.text)
    time.sleep(1)
    
    #scraping source of income
    source= driver.find_elements_by_xpath("//div[@class='source']")
    for i in source:
        Source.append(i.text)    
    time.sleep(1)
        
    #scraping Age of billionaire
    industries= driver.find_elements_by_xpath("//div[@class='category']//div")
    for i in industries:
        industry.append(i.text)
        
    #scraping net_worth of billionaire
    net_worth= driver.find_elements_by_xpath("//div[@class='netWorth']//div[1]")
    for i in net_worth:
        total_net_worth.append(i.text)
    time.sleep(1)    
        
    try:
        next_button = driver.find_element_by_xpath("//button[@class='pagination-btn pagination-btn--next ']")
        next_button.click()
    except:
        break  

        
Net_Worth = []        
for i in range(0,len(total_net_worth),2):
        Net_Worth.append(total_net_worth[i])
    

time.sleep(2)        
#creating dataframe
df=pd.DataFrame({'Rank':Rank,
                'Name':Person_Name,
                'Net Worth':Net_Worth,
                'Age':Age,
                'Country of Citizenship':country_of_citizenship,
                'Source':Source,
                'Industry':industry})
df
# Out:
# <ipython-input-4-1829c44a780d>:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")
# <ipython-input-4-1829c44a780d>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
# <ipython-input-4-1829c44a780d>:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   billioners = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
# <ipython-input-4-1829c44a780d>:30: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   world_billioners= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
# <ipython-input-4-1829c44a780d>:47: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rank= driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-4-1829c44a780d>:53: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name= driver.find_elements_by_xpath("//div[@class='personName']//div")
# <ipython-input-4-1829c44a780d>:59: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age= driver.find_elements_by_xpath("//div[@class='age']//div")
# <ipython-input-4-1829c44a780d>:65: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   citizenship= driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-4-1829c44a780d>:71: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   source= driver.find_elements_by_xpath("//div[@class='source']")
# <ipython-input-4-1829c44a780d>:77: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   industries= driver.find_elements_by_xpath("//div[@class='category']//div")
# <ipython-input-4-1829c44a780d>:82: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   net_worth= driver.find_elements_by_xpath("//div[@class='netWorth']//div[1]")
# <ipython-input-4-1829c44a780d>:88: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   next_button = driver.find_element_by_xpath("//button[@class='pagination-btn pagination-btn--next ']")
#        Rank                      Name Net Worth Age Country of Citizenship  \
# 0        1.                Jeff Bezos    $177 B  57          United States
# 1        2.                 Elon Musk    $151 B  49          United States
# 2        3.  Bernard Arnault & family    $150 B  72                 France
# 3        4.                Bill Gates    $124 B  65          United States
# 4        5.           Mark Zuckerberg     $97 B  36          United States
# ...     ...                       ...       ...  ..                    ...
# 2750  2674.         Daniel Yong Zhang      $1 B  49                  China
# 2751  2674.             Zhang Yuqiang      $1 B  65                  China
# 2752  2674.             Zhao Meiguang      $1 B  58                  China
# 2753  2674.            Zhong Naixiong      $1 B  58                  China
# 2754  2674.           Zhou Wei family      $1 B  54                  China
#
#              Source          Industry
# 0            Amazon        Technology
# 1     Tesla, SpaceX        Automotive
# 2              LVMH  Fashion & Retail
# 3         Microsoft        Technology
# 4          Facebook        Technology
# ...             ...               ...
# 2750     e-commerce        Technology
# 2751     Fiberglass     Manufacturing
# 2752    gold mining   Metals & Mining
# 2753   conglomerate       Diversified
# 2754       Software        Technology
#
# [2755 rows x 7 columns]

# %% [markdown]
# Q6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –
# September 20) from trak.in

# %%
Q6# Activating the chrome browser
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
time.sleep(2)

# opening trak.in
url = "https://trak.in/"
driver.get(url)
time.sleep(2)

# do click on funding deals
button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(button)

# Empty lists
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []


for i in range(48,51):
    # Date
    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        fund_dict['Date'].append(d.text)

    # Startup Name
    sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        fund_dict['Startup Name'].append(n.text)
    
    # Industry/Vertical
    ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)
    
    # Sub-Vertical
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    
    # Investor
    inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    
    # Amount
    amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)
    
fund_df = pd.DataFrame(fund_dict)
fund_df
# Out:
# <ipython-input-3-9ab4cac75edf>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")
# <ipython-input-3-9ab4cac75edf>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
# <ipython-input-3-9ab4cac75edf>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
# <ipython-input-3-9ab4cac75edf>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
# <ipython-input-3-9ab4cac75edf>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
# <ipython-input-3-9ab4cac75edf>:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
# <ipython-input-3-9ab4cac75edf>:48: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
# <ipython-input-3-9ab4cac75edf>:53: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
# <ipython-input-3-9ab4cac75edf>:58: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
# <ipython-input-3-9ab4cac75edf>:63: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
#           Date               Startup Name  \
# 0   15/07/2020                   Flipkart
# 1   16/07/2020                    Vedantu
# 2   16/07/2020                       Crio
# 3   14/07/2020                    goDutch
# 4   13/07/2020                   Mystifly
# 5   09/07/2020               JetSynthesys
# 6   10/07/2020                   gigIndia
# 7   15/07/2020                  PumPumPum
# 8   14/07/2020                       FLYX
# 9   13/07/2020  Open Appliances Pvt. Ltd.
# 10  15/08/2020                     Practo
# 11  13/08/2020                    Medlife
# 12  13/08/2020                  HungerBox
# 13  04/08/2020                      Dunzo
# 14  11/08/2020                   Terra.do
# 15  12/08/2020                  Classplus
# 16  14/08/2020                       Niyo
# 17  10/08/2020                  ZestMoney
# 18  07/08/2020                FreshToHome
# 19  13/08/2020                    Eduvanz
# 20  08/09/2020                     Byju’s
# 21  12/09/2020                  mCaffeine
# 22  09/09/2020                     Qshala
# 23  02/09/2020                      Winzo
# 24  09/09/2020                Hippo Video
# 25  07/09/2020                    Melorra
# 26  07/09/2020                        1mg
# 27  31/08/2020                      mfine
# 28  31/08/2020                       Apna
# 29  03/09/2020                    Railofy
#
#                          Industry/Vertical  \
# 0                               E-commerce
# 1                                  EduTech
# 2                                  EduTech
# 3                                  FinTech
# 4                      Airfare Marketplace
# 5                 Gaming and Entertainment
# 6                              Marketplace
# 7                        Automotive Rental
# 8                               OTT Player
# 9                   Information Technology
# 10                              HealthTech
# 11                              E-commerce
# 12                                FoodTech
# 13                   Hyper-local Logistics
# 14                                 EduTech
# 15                                 EduTech
# 16                                 FinTech
# 17                                 FinTech
# 18                              E-commerce
# 19                                 FinTech
# 20                                 EduTech
# 21                           Personal Care
# 22                                 EduTech
# 23                           Online Gaming
# 24  Video Customer Experience(CX) Platform
# 25                              E-commerce
# 26                              E-commerce
# 27                              HealthTech
# 28                         Human Resources
# 29                          Transportation
#
#                                          Sub-Vertical  \
# 0                                          E-commerce
# 1                                     Online Tutoring
# 2                    Learning Platform for Developers
# 3                                      Group Payments
# 4   Ticketing, Airline Retailing, and Post-Ticketi...
# 5                            Gaming and Entertainment
# 6                           Crowd Sourcing, Freelance
# 7                           Used Car-leasing platform
# 8                            Streaming Social Network
# 9               Internet-of-Things Security Solutions
# 10                           Health care and Wellness
# 11                                    Online Pharmacy
# 12                       Online Food Delivery Service
# 13                           Online Delivery Services
# 14                  Online Climate School, E-learning
# 15                        E-learning, Online Tutoring
# 16                                 Financial Services
# 17                                 Financial Services
# 18                                      Food Delivery
# 19                                 Financial Services
# 20                                    Online Tutoring
# 21                                Skincare & Haircare
# 22                 Online Curiosity Platform for Kids
# 23                                      Online Gaming
# 24             Video Customer Experience(CX) Platform
# 25                               Online Jewelry Store
# 26                                    Online Pharmacy
# 27                      On-Demand Healthcare Services
# 28                               Recruitment Platform
# 29                       WL & RAC protection platform
#
#                                       Location  \
# 0                                    Bangalore
# 1                                    Bangalore
# 2                                    Bangalore
# 3                                       Mumbai
# 4                      Singapore and Bangalore
# 5                                         Pune
# 6                                         Pune
# 7                                      Gurgaon
# 8                           New York and Delhi
# 9                                    Bangalore
# 10                                   Bangalore
# 11                                   Bangalore
# 12                                   Bangalore
# 13                                   Bangalore
# 14                       Stanford, California,
# 15                                       Noida
# 16                                   Bangalore
# 17                                   Bangalore
# 18                                   Bangalore
# 19                                      Mumbai
# 20                                   Bangalore
# 21                                      Mumbai
# 22                                   Bangalore
# 23                                   New Delhi
# 24  Newark, Delaware, United States of Amercia
# 25                                   Bangalore
# 26                                     Gurgaon
# 27                                   Bangalore
# 28                                   Bangalore
# 29                                      Mumbai
#
#                                              Investor         Investment Type  \
# 0                                         Walmart Inc                     M&A
# 1                                   Coatue Management                Series D
# 2                                         021 Capital            pre-Series A
# 3   Matrix India,Y Combinator, Global Founders Cap...                    Seed
# 4                                    Recruit Co. Ltd.            pre-Series B
# 5            Adar Poonawalla and Kris Gopalakrishnan.  Venture-Series Unknown
# 6        Incubate Fund India and Beyond Next Ventures            pre-Series A
# 7                            Early Adapters Syndicate                    Seed
# 8               Raj Mishra, founder of AIT Global Inc                pre-Seed
# 9                              Unicorn India Ventures  Venture-Series Unknown
# 10                                        A1A Company                Series F
# 11         Prasid Uno Family Trust and SC Credit Fund
# 12  One97, Sabre Partners Trust, Pratithi Investme...               Series D1
# 13                                   Existing Backers             In Progress
# 14  Stanford Angels and Entrepreneurs (India), BEE...                    Seed
# 15                                        Falcon Edge             In Progress
# 16                                Niyo Solutions Inc.
# 17                            Primrose Hills Ventures
# 18                                     Ascent Capital                 Venture
# 19                              Sequoia India, Unitus                Series A
# 20  Silver Lake, Tiger Global, General Atlantic an...          Private Equity
# 21  Amicus Capital Private Equity I LLP, Amicus Ca...                Series B
# 22                                 Rainmatter Capital                   Angel
# 23  Kalaari Capital Partners, IndigoEdge Managemen...                Series B
# 24  Alpha Wave Incubation, Exfinity Venture Partne...                Series A
# 25                         Shadow Holdings, Lightbox.          Debt Financing
# 26         Gaja Capital, Tata Capital, Partners Group             In Progress
# 27                                   Caretech Pte Inc                Series B
# 28         Lightspeed India and Sequoia Capital India                Series A
# 29                                  Chiratae Ventures                    Seed
#
#      Amount(in USD)
# 0     1,200,000,000
# 1       100,000,000
# 2           934,160
# 3         1,700,000
# 4         3,300,000
# 5           400,000
# 6           974,200
# 7           292,800
# 8           200,000
# 9           500,000
# 10       32,000,000
# 11       23,000,000
# 12        1,560,000
# 13       30,000,000
# 14        1,400,000
# 15  upto 15,000,000
# 16        6,000,000
# 17       10,670,000
# 18       16,200,000
# 19        5,000,000
# 20      500,000,000
# 21        3,000,000
# 22          370,000
# 23       15,500,000
# 24        4,500,000
# 25   upto 8,900,000
# 26      100,000,000
# 27        5,400,000
# 28        8,000,000
# 29          950,000

# %% [markdown]
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment
# was posted from any YouTube Video.

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")
time.sleep(2)

# Opening the youtube.com
url = "https://www.youtube.com/"
driver.get(url)
time.sleep(2)

#finding element for search bar
search_bar = driver.find_element_by_id('search')
search_bar.send_keys("GOT")  #entering Video name
time.sleep(1)

#clicking on search button
search_btn = driver.find_element_by_id("search-icon-legacy")  
search_btn.click()
time.sleep(1)

#clicking on first video
link_click = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link_click.click()
# 1000 time we scroll down by 10000 in order to generate more Comments
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")
#make empty lists
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

#scrape comments
cm = driver.find_elements_by_id("content-text")
for i in cm:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)
time.sleep(5)


# scrape time when comment was posted
tm = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
for i in tm:
    Time.append(i.text)

for i in range(0,len(Time),2):
    comment_time.append(Time[i])
time.sleep(5)
    
# scrape the comment likes
like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
    
    
time.sleep(2)
#creating dataframe
df=pd.DataFrame({'Comments':comments,
                'Time':comment_time,
                'Likes':No_of_Likes})
df

# %% [markdown]
# Q10. Write a python program to scrape a data for all available Hostels from
# https://www.hostelworld.com/ in “London” location. You have to scrape hostel name,
# distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms
# from price, facilities and property description.

# %%
driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver") 
time.sleep(3)

url = "https://www.hostelworld.com/"
driver.get(url)
# Out:
# <ipython-input-18-da15ef5b4465>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r"C:/Users/91976/Downloads/chromedriver_win32/chromedriver")

# %%
search_bar = driver.find_element_by_id("location-text-input-field")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys("London,England")
# Out:
# <ipython-input-19-e431e00c72ec>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_id("location-text-input-field")    # Locating searc_bar by id

# %%
titles_tags=driver.find_elements_by_xpath("//h2[@class = 'title title-6']")
titles_tags
# Out:
# <ipython-input-21-d7bcec9c20e7>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   titles_tags=driver.find_elements_by_xpath("//h2[@class = 'title title-6']")
# [<selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="c1c7dab1-fba9-4fcc-96d3-ed1355b27953")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="22c5038d-7878-4f2f-9f1c-788461351eb9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="61708bb6-d155-4fc9-8781-e56100b41686")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="14e4c313-b19d-4c54-9bd0-d0afbc09a124")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="3bf33c54-11c3-42f7-ae38-0ce66d36a442")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="3fb7a64b-2b3f-420e-9466-f77b044e68a9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b1a5904f-af02-4885-a7f2-8fc704001bef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="f09f99cb-8962-4138-80f1-caa194c83d7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="912a5e73-b86a-4ce7-92ca-e36ccda9b9f4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="965a3e74-9240-47d9-a1d0-99b4566c3a8d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="1900c25e-2821-4404-99f3-5c2cf2c9a470")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="fd164bd2-dd03-43d5-9782-b1b822f44191")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="ac3e40e2-3ddd-4045-9d17-942daf179025")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="55b192ec-9a06-4469-ae39-2135af20a5e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="cdcc3234-8379-48fd-b702-d47b632cc397")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="eaafde4d-74e7-43cd-b814-600f7c43b05d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="4609f638-779b-4e24-b032-bc9f16b7684e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="04e4a8ec-853e-4e1b-b20d-a88d7204aa65")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="0da68791-5a0f-4071-aa40-c06f6ea14aa4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b47df15f-aede-48a4-b4e1-c33ef4a7dd2f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="ba6eefd6-4b88-4f17-84ba-2b3ead019f02")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7c561b01-ba2b-4b1b-9375-882621b8329d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="f9f5a0ee-4b21-48c7-bcfa-b8bc7a7eeba4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="a62b511e-cf62-4a9a-9480-709b27b25120")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="785831da-ecb2-4058-988c-8c7eb27376a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5a7d8e0f-d224-4100-b12a-002d421e17a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="1cd700e4-d168-4d65-a880-24489683c28d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b8bbc0cc-ab0c-43cb-9fae-94cf30eb2234")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="9a2f3907-8eda-4b14-a2e9-9c88c346eb48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5ea885e9-c64a-418a-8b85-4807b0851fc4")>]

# %%
# Now the text of the hostel title is inside the tags extracted above.

# so we will run a loop to iterate over the tags extracted above and extract the text inside them.
hostel_titles=[]
for i in titles_tags[:10]:
    hostel_titles.append(i.text)
hostel_titles
# Out:
# ['Smart Russell Square Hostel',
#  'Smart Camden Inn Hostel',
#  'Selina Camden',
#  'Queen Elizabeth Chelsea',
#  'New Cross Inn Hostel',
#  'No.8 Willesden Hostel London',
#  'Safestay London Elephant & Castle',
#  'Barmy Badger Backpackers',
#  'The London Home Hostel',
#  'The Finnish Church in London']

# %%
# so lets extract all the tags having the city names
cities_tags=driver.find_elements_by_xpath("//span[@class = 'description']")
cities_tags
# Out:
# <ipython-input-23-a27d1a431102>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cities_tags=driver.find_elements_by_xpath("//span[@class = 'description']")
# [<selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="deb78669-1ab3-41dc-8ee6-97a7c07e764b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="f5b57969-40f0-4709-b34f-8831b4fa6b5d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="44c43c77-b833-44ef-807d-1af2a82d24e9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="83ed67e9-1fff-4738-b00d-bce92b01b864")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="fd3a4923-73b4-46f5-9853-b33fab5dda90")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7bd97813-bc28-424a-a96d-0d28f04f6787")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="c68800bb-08b1-4178-ae7d-7ff7fa57f7a5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="012a14c6-32a8-4334-baec-62fd403228c9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="bd76b0ee-5659-498f-ae52-6d03af4a47da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="140e2dd3-c615-464a-91f7-982e87b02d06")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="098b5bf3-ad99-4251-b6ad-a0c2d36fdbc1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="fdb4fad9-3382-4491-a672-ea562a54fac6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="edd4cb67-6d42-473c-89fa-ae52d3dfd8b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="06eaeb33-f253-4e29-baa1-54d19d74a85f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="58323db4-3133-4903-9927-a04792b8dfa4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="6bdd37c7-25f6-4e65-9770-8f8876245e31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="c2f80ab0-1174-4372-b5d7-4a74fe0233c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b5ad5dc9-b9ea-4b6b-8f6e-21cc6da7c0d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="d02552ac-ed4d-42b2-a908-8d5010fef38a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5d6a1397-d0e8-4e1f-937a-d72ee3715e35")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="915ffc09-f75b-4330-8648-f5c9bb5c7a0a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="24e961a6-13c6-40f2-b303-5a3eba76c88a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="8159b8f2-c40d-4ebe-b1bf-ccecccf12a2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="43e44c66-98a6-4b08-8d94-952bbd0c75f2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="26893348-cad9-467e-9d50-d6feacc63014")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="ccafd809-dd2a-4efc-aba0-9e7c4cb0f9e1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="401e038e-6735-4439-95d9-84c514f88e12")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="62f331d5-90ad-4193-a5d7-112f6108170c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5c040cb7-0245-4ef9-a57e-13d86942d020")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="e1a8f800-3ea3-4310-af34-4ffdd6b125d9")>]

# %%
city_names=[]

for i in cities_tags[:10]:
    city_names.append(i.text)
city_names
# Out:
# ['Hostel - 2.6km from city centre',
#  'Hostel - 4.4km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 5.7km from city centre',
#  'Hostel - 6.1km from city centre',
#  'Hostel - 10km from city centre',
#  'Hostel - 1.7km from city centre',
#  'Hostel - 5.5km from city centre',
#  'Hostel - 8.2km from city centre',
#  'Hostel - 4.5km from city centre']

# %%
# so lets extract all the tags having the review required data 
review_tags=driver.find_elements_by_xpath("//div[@class = 'reviews']")
review_tags
# Out:
# <ipython-input-25-402468a3b4fc>:2: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   review_tags=driver.find_elements_by_xpath("//div[@class = 'reviews']")
# [<selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="f9cf7714-5db6-4d8c-8102-44930614e7b3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="46cfa9a7-82b0-48ba-bc04-715b18dc8103")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="09bd41c7-1e3f-4fb2-82ec-d3402521ab74")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="c1581683-9c5c-44ae-9b2e-fde2ab5a945c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="235d5c66-ec5e-4acb-af1c-fb5c872c3398")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="45797ea5-62ec-4047-9701-62a35285d09f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="e4a9ed7d-722a-4018-85f0-b030657a0550")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b0b93692-c9b8-44d9-a125-a669dd462662")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="82773969-291e-4403-80f0-12b021b6e312")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="09d48919-86cb-4736-b0b6-fea355fc56ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="d271323f-85ba-4dd7-bab8-52f320969163")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b2c0a101-f7df-48ba-bba1-eb02bf4929ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="29c281eb-60eb-4bd8-9e9b-7fa1e50de3f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="087fc3ca-e43c-4546-a119-9e5599e12bec")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b1a0e746-17aa-4e08-9de5-0e7abc58f6c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b578a0b2-5011-41e2-89ba-33004cafc8f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="61423aa6-80f2-498d-b0f5-d36c8e95087d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7de95f5c-52aa-4155-a010-a810a0569765")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="03ed0b61-f7c3-450a-bd6e-06cee6915a60")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="afd47883-106f-40f2-a04b-0f5bacb1eaaa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b229311d-4598-4455-a919-1f5dc7daa3c0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="16e4b937-06a6-45c8-92ba-7c4205eca8d4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7a06da26-e579-4977-bcad-489da937ad99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7f49fc80-a869-4d74-84f9-c2a18508d918")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="f54986cf-061a-43ed-9590-8d89e1606084")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="a88292d8-bf0b-4c95-ae49-f40fc4ee41e2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5c8a0f57-8b26-4a07-8e60-dc89b66509ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="26df4871-b93d-40f5-9e74-0a88c6dd3254")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="92711a1d-b338-4d80-a192-f9d71ff3fde7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="29efef31-ff18-4963-ad4d-5078bd8d9bb7")>]

# %%
review_list=[]
for i in review_tags[:10]:
    review_list.append(i.text)
review_list

# so lets extract all the tags having the price names
prices_tags=driver.find_elements_by_xpath("//div[@class = 'price title-5']")
prices_tags
# Out:
# <ipython-input-26-4d705129546f>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   prices_tags=driver.find_elements_by_xpath("//div[@class = 'price title-5']")
# [<selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="36cf2480-bab6-44e8-9dd4-7457880588ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7d70a926-c14d-4d1a-980b-7775798d6acd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="a1020860-668d-4089-84d7-a29fb04252cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="8cbe6bac-7054-4bda-a85f-86d92af92be3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="fda901db-07d6-469b-8e9d-188bc5a419ac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="12aad39a-0a5d-4fc2-b23f-211d8bcffbf1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="497853eb-8b0d-4ce4-9c80-149e50861f2d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="20f77787-e81b-4c37-b49f-2b1534243a51")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="255f29d6-1e57-4521-b685-40d2a3fee4ba")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="6ed16612-8f5c-444b-8f77-8520a25417ca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="e0cf2c3c-c194-4ed6-a314-723df70d99a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="8fa73791-11fd-4a07-aa45-f947f6d946cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="bb109e71-80cc-4ca6-9cfd-bc70b26340a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="3400508c-b5dc-40be-9adb-9fad4d0255ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="1db09de7-daf1-4063-8cc5-d2e637228b9a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="19d0ef59-20f3-4b9e-834f-d425e8a922c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="04f7ae78-f8f7-4c86-88cf-08f78a523160")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="9ccf3893-e2f5-44b0-8689-31757b5909c5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7e9b3c46-0d4b-4103-8df6-045911cc4cbe")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="f91fe9c0-bc09-4227-acf2-2afb5fc8db92")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="030ecb6f-84b1-4524-a757-6c7105dad06e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5cc6e4f3-3cce-45df-9266-ccfb94d47a7c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5158f75b-982a-47c1-9afc-6195b9e4b758")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="72f33571-74fc-49e8-bbc7-0e540771c4f6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="37a41739-1d7f-4ea8-9111-ac748faa381e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="636cbed7-52dc-4bb6-8680-77fdfb25f58a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="1eee2330-36ff-40f2-a360-7dbed8bb0b6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="0ec4c932-8439-4320-9f51-679849c22ca9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="53db951d-23c0-4ae3-9899-b9c2aeee0ba2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="dccfdbd4-3570-4b96-934f-1d18d1d4297c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="d59ebb78-9b8a-4c69-b054-aee1a338c25b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="2d111ffd-a9d7-48fc-b53e-2dd564acc3ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="2757fc9c-e00e-4d2d-aa0e-2047d1bf4b9c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="cf792d62-b69e-4587-a833-39dc920ef047")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="f7e1df01-f3d5-4115-8a48-1d35a71c96b9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="57f7f4c6-a9ac-459f-89d6-e49bccec3652")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="541a47d9-c08b-4073-ae98-a902bb75c4bb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="d635cae1-ee4e-475c-9617-48e7c30c1294")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="0d3502e7-9ca7-4f04-98eb-adeccab5a4b1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="820bff04-6153-4877-8d90-b51824cfbda6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="cf483304-40f3-4d5b-9af7-28e18d0a7053")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="7c62fed6-dfe6-4352-8803-f1c5449a22a8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="5addc294-50a0-409f-b3c7-c41acb42096e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="ba11a9bf-42bd-4514-af07-37341b64344b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="3513dab1-d541-4497-8239-961aa2046138")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="dcb4540e95c65fcaa93f0b1345d898b0", element="b20ad34a-18d8-4ec1-be69-c32d4457d233")>]

# %%
price_names=[]

for i in prices_tags[:10]:
    price_names.append(i.text)
price_names
# Out:
# ['Rs1586',
#  'Rs1608',
#  'Rs18461',
#  'Rs5274.35 Rs4483',
#  'Rs4899',
#  'Rs1718',
#  'Rs11922',
#  'Rs3684',
#  'Rs815',
#  'Rs6329']

# %%
#import pandas as pd 
titles=pd.DataFrame({})
titles['Name']=hostel_titles
titles['cities']=city_names
titles['reviews']=review_list
titles['Price']=price_names
titles
# Out:
#                                 Name                           cities  \
# 0        Smart Russell Square Hostel  Hostel - 2.6km from city centre
# 1            Smart Camden Inn Hostel  Hostel - 4.4km from city centre
# 2                      Selina Camden  Hostel - 5.5km from city centre
# 3            Queen Elizabeth Chelsea  Hostel - 5.7km from city centre
# 4               New Cross Inn Hostel  Hostel - 6.1km from city centre
# 5       No.8 Willesden Hostel London   Hostel - 10km from city centre
# 6  Safestay London Elephant & Castle  Hostel - 1.7km from city centre
# 7           Barmy Badger Backpackers  Hostel - 5.5km from city centre
# 8             The London Home Hostel  Hostel - 8.2km from city centre
# 9       The Finnish Church in London  Hostel - 4.5km from city centre
#
#               reviews             Price
# 0  9555 Total Reviews            Rs1586
# 1  2727 Total Reviews            Rs1608
# 2    13 Total Reviews           Rs18461
# 3  3208 Total Reviews  Rs5274.35 Rs4483
# 4  1041 Total Reviews            Rs4899
# 5  4623 Total Reviews            Rs1718
# 6  4014 Total Reviews           Rs11922
# 7  1685 Total Reviews            Rs3684
# 8   253 Total Reviews             Rs815
# 9   197 Total Reviews            Rs6329
